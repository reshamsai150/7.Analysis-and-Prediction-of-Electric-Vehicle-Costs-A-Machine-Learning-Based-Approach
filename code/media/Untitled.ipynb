# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\MMC\Desktop\projectin EV\media\ElectricCarData_Clean_Me.csv')
df
# Out:
#           Brand                            Model  AccelSec  TopSpeed_KmH  \
# 0         Tesla    Model 3 Long Range Dual Motor       4.6           233
# 1    Volkswagen                        ID.3 Pure      10.0           160
# 2      Polestar                                2       4.7           210
# 3           BMW                              iX3       6.8           180
# 4         Honda                                e       9.5           145
# ..          ...                              ...       ...           ...
# 97       Nissan                      Ariya 63kWh       7.5           160
# 98         Audi    e-tron S Sportback 55 quattro       4.5           210
# 99       Nissan              Ariya e-4ORCE 63kWh       5.9           200
# 100      Nissan  Ariya e-4ORCE 87kWh Performance       5.1           200
# 101       Byton                M-Byte 95 kWh 2WD       7.5           190
#
#      Range_Km  Battery_Pack Kwh  Efficiency_WhKm  FastCharge_KmH RapidCharge  \
# ...

# %%
df1 = df.drop(['Brand','Model'],axis=1)
df1
# Out:
#      AccelSec  TopSpeed_KmH  Range_Km  Battery_Pack Kwh  Efficiency_WhKm  \
# 0         4.6           233       460              70.0              161
# 1        10.0           160       270              45.0              167
# 2         4.7           210       400              75.0              181
# 3         6.8           180       360              74.0              206
# 4         9.5           145       170              28.5              168
# ..        ...           ...       ...               ...              ...
# 97        7.5           160       330              63.0              191
# 98        4.5           210       335              86.5              258
# 99        5.9           200       325              63.0              194
# 100       5.1           200       375              87.0              232
# 101       7.5           190       400              95.0              238
#
#      FastCharge_KmH RapidCharge PowerTrain    PlugType  BodyStyle Segment  \
# ...

# %%
df1.isna().sum()
# Out:
# AccelSec            0
# TopSpeed_KmH        0
# Range_Km            0
# Battery_Pack Kwh    0
# Efficiency_WhKm     0
# FastCharge_KmH      0
# RapidCharge         0
# PowerTrain          0
# PlugType            0
# BodyStyle           0
# Segment             0
# Seats               0
# PriceEuro           0
# dtype: int64

# %%
column_mappings = {
            'RapidCharge':{'Yes':1,'No':0},
            'PlugType':{'Type 2 CCS':1,'Type 2':2,'Type 2 CHAdeMO':3},
            'PowerTrain':{'AWD':1,'FWD':2,'RWD':3},
            'BodyStyle':{'SUV':1,'Hatchback':2,'Sedan':3,'Liftback':4,'Pickup':5,'Cabrio':6,'SPV':7},
            'Segment':{'C':1,'B':2,'D':3,'F':4,'E':5,'A':6,'N':7}
        }              
df1.replace(column_mappings, inplace=True)
print(df1)
# Out:
#      AccelSec  TopSpeed_KmH  Range_Km  Battery_Pack Kwh  Efficiency_WhKm  \
# 0         4.6           233       460              70.0              161
# 1        10.0           160       270              45.0              167
# 2         4.7           210       400              75.0              181
# 3         6.8           180       360              74.0              206
# 4         9.5           145       170              28.5              168
# ..        ...           ...       ...               ...              ...
# 97        7.5           160       330              63.0              191
# 98        4.5           210       335              86.5              258
# 99        5.9           200       325              63.0              194
# 100       5.1           200       375              87.0              232
# 101       7.5           190       400              95.0              238
#
#      FastCharge_KmH  RapidCharge  PowerTrain PlugType BodyStyle Segment  \
# ...

# %%
df1.isna().sum()
# Out:
# AccelSec            0
# TopSpeed_KmH        0
# Range_Km            0
# Battery_Pack Kwh    0
# Efficiency_WhKm     0
# FastCharge_KmH      0
# RapidCharge         0
# PowerTrain          0
# PlugType            0
# BodyStyle           0
# Segment             0
# Seats               0
# PriceEuro           0
# dtype: int64

# %%
# Compute the correlation matrix       
X = df1[[x for x in df1.columns if x!='PriceEuro']]
# X = pd.get_dummies(X)

# %%
df1.isna().sum()
# Out:
# AccelSec            0
# TopSpeed_KmH        0
# Range_Km            0
# Battery_Pack Kwh    0
# Efficiency_WhKm     0
# FastCharge_KmH      0
# RapidCharge         0
# PowerTrain          0
# PlugType            0
# BodyStyle           0
# Segment             0
# Seats               0
# PriceEuro           0
# dtype: int64

# %%
# Compute the correlation matrix       
X = df1[[x for x in df1.columns if x!='PriceEuro']]
# X = pd.get_dummies(X)

# %%
y = X.isna().sum()

# %%
y
# Out:
# AccelSec            0
# TopSpeed_KmH        0
# Range_Km            0
# Battery_Pack Kwh    0
# Efficiency_WhKm     0
# FastCharge_KmH      0
# RapidCharge         0
# PowerTrain          0
# PlugType            0
# BodyStyle           0
# Segment             0
# Seats               0
# dtype: int64

# %%
X.to_csv("ElectricCarData_Modified.csv", index=False)

# %%
X
# Out:
#      AccelSec  TopSpeed_KmH  Range_Km  Battery_Pack Kwh  Efficiency_WhKm  \
# 0         4.6           233       460              70.0              161
# 1        10.0           160       270              45.0              167
# 2         4.7           210       400              75.0              181
# 3         6.8           180       360              74.0              206
# 4         9.5           145       170              28.5              168
# ..        ...           ...       ...               ...              ...
# 97        7.5           160       330              63.0              191
# 98        4.5           210       335              86.5              258
# 99        5.9           200       325              63.0              194
# 100       5.1           200       375              87.0              232
# 101       7.5           190       400              95.0              238
#
#      FastCharge_KmH  RapidCharge  PowerTrain PlugType BodyStyle Segment  Seats
# ...

# %%
X.isna().sum()
# Out:
# AccelSec            0
# TopSpeed_KmH        0
# Range_Km            0
# Battery_Pack Kwh    0
# Efficiency_WhKm     0
# FastCharge_KmH      0
# RapidCharge         0
# PowerTrain          0
# PlugType            0
# BodyStyle           0
# Segment             0
# Seats               0
# dtype: int64
